# %% [markdown]
# # 建立wordleBOT
# ## 遊戲程式
# 1. ans_dic, pos_dic
# 2. rand_answer(ans_dic)
# 3. guess()
# 4. word_compare()

# %%
import sys
sys.path.append('../data')
from answer import dictionary
import random

# %%
dictionary
# Out:
# ['aback',
#  'abase',
#  'abate',
#  'abbey',
#  'abbot',
#  'abhor',
#  'abide',
#  'abled',
#  'abode',
#  'abort',
#  'about',
#  'above',
#  'abuse',
#  'abyss',
#  'acorn',
#  'acrid',
#  'actor',
#  'acute',
#  'adage',
#  'adapt',
#  'adept',
#  'admin',
#  'admit',
#  'adobe',
#  'adopt',
#  'adore',
#  'adorn',
#  'adult',
#  'affix',
#  'afire',
#  'afoot',
#  'afoul',
#  'after',
#  'again',
#  'agape',
#  'agate',
#  'agent',
#  'agile',
#  'aging',
#  'aglow',
#  'agony',
#  'agora',
#  'agree',
#  'ahead',
#  'aider',
#  'aisle',
#  'alarm',
#  'album',
#  'alert',
#  'algae',
#  'alibi',
#  'alien',
#  'align',
#  'alike',
#  'alive',
#  'allay',
#  'alley',
#  'allot',
#  'allow',
#  'alloy',
#  'aloft',
#  'alone',
#  'along',
#  'aloof',
#  'aloud',
#  'alpha',
#  'altar',
#  'alter',
#  'amass',
#  'amaze',
#  'amber',
#  'amble',
#  'amend',
#  'amiss',
#  'amity',
#  'among',
#  'ample',
#  'amply',
#  'amuse',
#  'angel',
#  'anger',
#  'angle',
#  'angry',
# ...

# %%
class Wordle():
    def __init__(self, pos_dic,real_dic,first_guess=""):
        self.pos_w = pos_dic
        self.real_w = real_dic
        self.counter = 0
    def get_ans(self):
        return random.choice(self.real_w)
    def guess():
        return input()
    def word_compare(self):
        return
    def play(self):
        return

# %%
game = Wordle([],['a','b','c','d'])

# %%
game.get_ans()
# Out:
# 'c'

# %%
ddasdasdasdasdqweqwe

# %%
dddd
